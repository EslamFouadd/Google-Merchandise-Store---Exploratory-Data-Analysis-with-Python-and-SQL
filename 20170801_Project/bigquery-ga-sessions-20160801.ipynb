# %% [markdown]
# # Google Merchandise Store - Exploratory Data Analysis with Python and SQL

# %% [markdown]
# # Step 1: Extract Data
#
# The sample dataset contains Google Analytics 360 data (01/08/2016 - 01/08/2017) from the Google Merchandise Store, a real ecommerce store. The goal of this analysis is to address some key questions in marketing/web analytics from different angles such as channel performance in terms of traffic and revenue, individual page performance, and checkout process performance. I mainly used Python Client for BigQuery library along with pandas and matplotlib libraries to extract, query, and visualize data.
#
# Data from: https://bigquery.cloud.google.com/table/bigquery-public-data:google_analytics_sample.ga_sessions_20170731

# %%
#Ignore warnings
import warnings
warnings.filterwarnings("ignore")

#Maths and Vectors
import pandas as pd
import numpy as np

#Visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
from google.cloud import bigquery
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Create a client object
client = bigquery.Client()

# Create a dataset reference
dataset_ref = client.dataset("google_analytics_sample", project = "bigquery-public-data")

# Retrieve a dataset from reference
dataset = client.get_dataset(dataset_ref)

# Check available tables in the dataset
for x in client.list_tables(dataset):
    print(x.table_id)
# Out:
# Using Kaggle's public dataset BigQuery integration.
# ga_sessions_20160801
# ga_sessions_20160802
# ga_sessions_20160803
# ga_sessions_20160804
# ga_sessions_20160805
# ga_sessions_20160806
# ga_sessions_20160807
# ga_sessions_20160808
# ga_sessions_20160809
# ga_sessions_20160810
# ga_sessions_20160811
# ga_sessions_20160812
# ga_sessions_20160813
# ga_sessions_20160814
# ga_sessions_20160815
# ga_sessions_20160816
# ga_sessions_20160817
# ga_sessions_20160818
# ga_sessions_20160819
# ga_sessions_20160820
# ga_sessions_20160821
# ga_sessions_20160822
# ga_sessions_20160823
# ga_sessions_20160824
# ga_sessions_20160825
# ga_sessions_20160826
# ga_sessions_20160827
# ga_sessions_20160828
# ga_sessions_20160829
# ga_sessions_20160830
# ga_sessions_20160831
# ga_sessions_20160901
# ga_sessions_20160902
# ga_sessions_20160903
# ga_sessions_20160904
# ga_sessions_20160905
# ga_sessions_20160906
# ga_sessions_20160907
# ga_sessions_20160908
# ga_sessions_20160909
# ga_sessions_20160910
# ga_sessions_20160911
# ga_sessions_20160912
# ga_sessions_20160913
# ga_sessions_20160914
# ga_sessions_20160915
# ga_sessions_20160916
# ga_sessions_20160917
# ga_sessions_20160918
# ga_sessions_20160919
# ga_sessions_20160920
# ga_sessions_20160921
# ga_sessions_20160922
# ga_sessions_20160923
# ga_sessions_20160924
# ga_sessions_20160925
# ga_sessions_20160926
# ga_sessions_20160927
# ga_sessions_20160928
# ga_sessions_20160929
# ga_sessions_20160930
# ga_sessions_20161001
# ga_sessions_20161002
# ga_sessions_20161003
# ga_sessions_20161004
# ga_sessions_20161005
# ga_sessions_20161006
# ga_sessions_20161007
# ga_sessions_20161008
# ga_sessions_20161009
# ga_sessions_20161010
# ga_sessions_20161011
# ga_sessions_20161012
# ga_sessions_20161013
# ga_sessions_20161014
# ga_sessions_20161015
# ga_sessions_20161016
# ga_sessions_20161017
# ga_sessions_20161018
# ga_sessions_20161019
# ga_sessions_20161020
# ga_sessions_20161021
# ga_sessions_20161022
# ga_sessions_20161023
# ga_sessions_20161024
# ga_sessions_20161025
# ga_sessions_20161026
# ga_sessions_20161027
# ga_sessions_20161028
# ga_sessions_20161029
# ga_sessions_20161030
# ga_sessions_20161031
# ga_sessions_20161101
# ga_sessions_20161102
# ga_sessions_20161103
# ga_sessions_20161104
# ga_sessions_20161105
# ga_sessions_20161106
# ga_sessions_20161107
# ga_sessions_20161108
# ga_sessions_20161109
# ga_sessions_20161110
# ga_sessions_20161111
# ga_sessions_20161112
# ga_sessions_20161113
# ga_sessions_20161114
# ga_sessions_20161115
# ga_sessions_20161116
# ga_sessions_20161117
# ga_sessions_20161118
# ga_sessions_20161119
# ga_sessions_20161120
# ga_sessions_20161121
# ga_sessions_20161122
# ga_sessions_20161123
# ga_sessions_20161124
# ga_sessions_20161125
# ga_sessions_20161126
# ga_sessions_20161127
# ga_sessions_20161128
# ga_sessions_20161129
# ga_sessions_20161130
# ga_sessions_20161201
# ga_sessions_20161202
# ga_sessions_20161203
# ga_sessions_20161204
# ga_sessions_20161205
# ga_sessions_20161206
# ga_sessions_20161207
# ga_sessions_20161208
# ga_sessions_20161209
# ga_sessions_20161210
# ga_sessions_20161211
# ga_sessions_20161212
# ga_sessions_20161213
# ga_sessions_20161214
# ga_sessions_20161215
# ga_sessions_20161216
# ga_sessions_20161217
# ga_sessions_20161218
# ga_sessions_20161219
# ga_sessions_20161220
# ga_sessions_20161221
# ga_sessions_20161222
# ga_sessions_20161223
# ga_sessions_20161224
# ga_sessions_20161225
# ga_sessions_20161226
# ga_sessions_20161227
# ga_sessions_20161228
# ga_sessions_20161229
# ga_sessions_20161230
# ga_sessions_20161231
# ga_sessions_20170101
# ga_sessions_20170102
# ga_sessions_20170103
# ga_sessions_20170104
# ga_sessions_20170105
# ga_sessions_20170106
# ga_sessions_20170107
# ga_sessions_20170108
# ga_sessions_20170109
# ga_sessions_20170110
# ga_sessions_20170111
# ga_sessions_20170112
# ga_sessions_20170113
# ga_sessions_20170114
# ga_sessions_20170115
# ga_sessions_20170116
# ga_sessions_20170117
# ga_sessions_20170118
# ga_sessions_20170119
# ga_sessions_20170120
# ga_sessions_20170121
# ga_sessions_20170122
# ga_sessions_20170123
# ga_sessions_20170124
# ga_sessions_20170125
# ga_sessions_20170126
# ga_sessions_20170127
# ga_sessions_20170128
# ga_sessions_20170129
# ga_sessions_20170130
# ga_sessions_20170131
# ga_sessions_20170201
# ga_sessions_20170202
# ga_sessions_20170203
# ga_sessions_20170204
# ga_sessions_20170205
# ga_sessions_20170206
# ga_sessions_20170207
# ga_sessions_20170208
# ga_sessions_20170209
# ga_sessions_20170210
# ga_sessions_20170211
# ga_sessions_20170212
# ga_sessions_20170213
# ga_sessions_20170214
# ga_sessions_20170215
# ga_sessions_20170216
# ga_sessions_20170217
# ga_sessions_20170218
# ga_sessions_20170219
# ga_sessions_20170220
# ga_sessions_20170221
# ga_sessions_20170222
# ga_sessions_20170223
# ga_sessions_20170224
# ga_sessions_20170225
# ga_sessions_20170226
# ga_sessions_20170227
# ga_sessions_20170228
# ga_sessions_20170301
# ga_sessions_20170302
# ga_sessions_20170303
# ga_sessions_20170304
# ga_sessions_20170305
# ga_sessions_20170306
# ga_sessions_20170307
# ga_sessions_20170308
# ga_sessions_20170309
# ga_sessions_20170310
# ga_sessions_20170311
# ga_sessions_20170312
# ga_sessions_20170313
# ga_sessions_20170314
# ga_sessions_20170315
# ga_sessions_20170316
# ga_sessions_20170317
# ga_sessions_20170318
# ga_sessions_20170319
# ga_sessions_20170320
# ga_sessions_20170321
# ga_sessions_20170322
# ga_sessions_20170323
# ga_sessions_20170324
# ga_sessions_20170325
# ga_sessions_20170326
# ga_sessions_20170327
# ga_sessions_20170328
# ga_sessions_20170329
# ga_sessions_20170330
# ga_sessions_20170331
# ga_sessions_20170401
# ga_sessions_20170402
# ga_sessions_20170403
# ga_sessions_20170404
# ga_sessions_20170405
# ga_sessions_20170406
# ga_sessions_20170407
# ga_sessions_20170408
# ga_sessions_20170409
# ga_sessions_20170410
# ga_sessions_20170411
# ga_sessions_20170412
# ga_sessions_20170413
# ga_sessions_20170414
# ga_sessions_20170415
# ga_sessions_20170416
# ga_sessions_20170417
# ga_sessions_20170418
# ga_sessions_20170419
# ga_sessions_20170420
# ga_sessions_20170421
# ga_sessions_20170422
# ga_sessions_20170423
# ga_sessions_20170424
# ga_sessions_20170425
# ga_sessions_20170426
# ga_sessions_20170427
# ga_sessions_20170428
# ga_sessions_20170429
# ga_sessions_20170430
# ga_sessions_20170501
# ga_sessions_20170502
# ga_sessions_20170503
# ga_sessions_20170504
# ga_sessions_20170505
# ga_sessions_20170506
# ga_sessions_20170507
# ga_sessions_20170508
# ga_sessions_20170509
# ga_sessions_20170510
# ga_sessions_20170511
# ga_sessions_20170512
# ga_sessions_20170513
# ga_sessions_20170514
# ga_sessions_20170515
# ga_sessions_20170516
# ga_sessions_20170517
# ga_sessions_20170518
# ga_sessions_20170519
# ga_sessions_20170520
# ga_sessions_20170521
# ga_sessions_20170522
# ga_sessions_20170523
# ga_sessions_20170524
# ga_sessions_20170525
# ga_sessions_20170526
# ga_sessions_20170527
# ga_sessions_20170528
# ga_sessions_20170529
# ga_sessions_20170530
# ga_sessions_20170531
# ga_sessions_20170601
# ga_sessions_20170602
# ga_sessions_20170603
# ga_sessions_20170604
# ga_sessions_20170605
# ga_sessions_20170606
# ga_sessions_20170607
# ga_sessions_20170608
# ga_sessions_20170609
# ga_sessions_20170610
# ga_sessions_20170611
# ga_sessions_20170612
# ga_sessions_20170613
# ga_sessions_20170614
# ga_sessions_20170615
# ga_sessions_20170616
# ga_sessions_20170617
# ga_sessions_20170618
# ga_sessions_20170619
# ga_sessions_20170620
# ga_sessions_20170621
# ga_sessions_20170622
# ga_sessions_20170623
# ga_sessions_20170624
# ga_sessions_20170625
# ga_sessions_20170626
# ga_sessions_20170627
# ga_sessions_20170628
# ga_sessions_20170629
# ga_sessions_20170630
# ga_sessions_20170701
# ga_sessions_20170702
# ga_sessions_20170703
# ga_sessions_20170704
# ga_sessions_20170705
# ga_sessions_20170706
# ga_sessions_20170707
# ga_sessions_20170708
# ga_sessions_20170709
# ga_sessions_20170710
# ga_sessions_20170711
# ga_sessions_20170712
# ga_sessions_20170713
# ga_sessions_20170714
# ga_sessions_20170715
# ga_sessions_20170716
# ga_sessions_20170717
# ga_sessions_20170718
# ga_sessions_20170719
# ga_sessions_20170720
# ga_sessions_20170721
# ga_sessions_20170722
# ga_sessions_20170723
# ga_sessions_20170724
# ga_sessions_20170725
# ga_sessions_20170726
# ga_sessions_20170727
# ga_sessions_20170728
# ga_sessions_20170729
# ga_sessions_20170730
# ga_sessions_20170731
# ga_sessions_20170801

# %%
# Create a table reference
table_ref_20170731 = dataset_ref.table("ga_sessions_20170731")

# Retrieve table from reference
table_20170731 = client.get_table(table_ref_20170731)

# View columns
client.list_rows(table_20170731, max_results = 5).to_dataframe()
# Out:
#    visitorId  visitNumber     visitId  visitStartTime      date  \
# 0        NaN            1  1501520683      1501520683  20170731
# 1        NaN            1  1501512773      1501512773  20170731
# 2        NaN            1  1501559508      1501559508  20170731
# 3        NaN            1  1501520907      1501520907  20170731
# 4        NaN            1  1501486642      1501486642  20170731
#
#                                               totals  \
# 0  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# 1  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# 2  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# 3  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# 4  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
#
#                                        trafficSource  \
# 0  {'referralPath': None, 'campaign': '(not set)'...
# 1  {'referralPath': None, 'campaign': '(not set)'...
# 2  {'referralPath': None, 'campaign': '(not set)'...
# 3  {'referralPath': None, 'campaign': '(not set)'...
# 4  {'referralPath': None, 'campaign': '(not set)'...
#
#                                               device  \
# 0  {'browser': 'Firefox', 'browserVersion': 'not ...
# 1  {'browser': 'Internet Explorer', 'browserVersi...
# 2  {'browser': 'Chrome', 'browserVersion': 'not a...
# 3  {'browser': 'Safari', 'browserVersion': 'not a...
# 4  {'browser': 'Chrome', 'browserVersion': 'not a...
#
#                                           geoNetwork  \
# 0  {'continent': 'Europe', 'subContinent': 'Easte...
# 1  {'continent': 'Europe', 'subContinent': 'North...
# 2  {'continent': 'Asia', 'subContinent': 'Southea...
# 3  {'continent': 'Europe', 'subContinent': 'South...
# 4  {'continent': 'Asia', 'subContinent': 'Southea...
#
#                   customDimensions  \
# 0                               []
# 1  [{'index': 4, 'value': 'EMEA'}]
# 2                               []
# 3                               []
# 4  [{'index': 4, 'value': 'APAC'}]
#
#                                                 hits        fullVisitorId  \
# 0  [{'hitNumber': 1, 'time': 0, 'hour': 10, 'minu...  2219384770970157334
# 1  [{'hitNumber': 1, 'time': 0, 'hour': 7, 'minut...  3257231109110009503
# 2  [{'hitNumber': 1, 'time': 0, 'hour': 20, 'minu...  1481009813315636845
# 3  [{'hitNumber': 1, 'time': 0, 'hour': 10, 'minu...  4042576478930992747
# 4  [{'hitNumber': 1, 'time': 0, 'hour': 0, 'minut...  1478324366289834997
#
#   userId clientId channelGrouping  socialEngagementType
# 0   None     None  Organic Search  Not Socially Engaged
# 1   None     None  Organic Search  Not Socially Engaged
# 2   None     None  Organic Search  Not Socially Engaged
# 3   None     None  Organic Search  Not Socially Engaged
# 4   None     None  Organic Search  Not Socially Engaged

# %% [markdown]
# **Some columns such as totals, trafficSource, device, geoNetwork, customDimensions, and hits contain nested data, hence, we would want to check the data schema of them.**

# %%
print("Schema Field of totals column \n")
print(table_20170731.schema[5].to_standard_sql(), end = "\n")

print("Schema Field of trafficSource column \n")
print(table_20170731.schema[6].to_standard_sql(), end = "\n")

print("Schema Field of device column \n")
print(table_20170731.schema[7].to_standard_sql(), end = "\n")

print("Schema Field of geoNetwork column \n")
print(table_20170731.schema[8].to_standard_sql(), end = "\n")

print("Schema Field of customDimensions column \n")
print(table_20170731.schema[9].to_standard_sql(), end = "\n")

print("Schema Field of hits column \n")
print(table_20170731.schema[10].to_standard_sql(), end = "\n")
# Out:
# Schema Field of totals column
#
# name: "totals"
# type {
#   type_kind: STRUCT
#   struct_type {
#     fields {
#       name: "visits"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "hits"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "pageviews"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "timeOnSite"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "bounces"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "transactions"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "transactionRevenue"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "newVisits"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "screenviews"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "uniqueScreenviews"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "timeOnScreen"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "totalTransactionRevenue"
#       type {
#         type_kind: INT64
#       }
#     }
#     fields {
#       name: "sessionQualityDim"
#       type {
#         type_kind: INT64
#       }
#     }
#   }
# }
#
# Schema Field of trafficSource column
#
# name: "trafficSource"
# type {
#   type_kind: STRUCT
#   struct_type {
#     fields {
#       name: "referralPath"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "campaign"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "source"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "medium"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "keyword"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "adContent"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "adwordsClickInfo"
#       type {
#         type_kind: STRUCT
#         struct_type {
#           fields {
#             name: "campaignId"
#             type {
#               type_kind: INT64
#             }
#           }
#           fields {
#             name: "adGroupId"
#             type {
#               type_kind: INT64
#             }
#           }
#           fields {
#             name: "creativeId"
#             type {
#               type_kind: INT64
#             }
#           }
#           fields {
#             name: "criteriaId"
#             type {
#               type_kind: INT64
#             }
#           }
#           fields {
#             name: "page"
#             type {
#               type_kind: INT64
#             }
#           }
#           fields {
#             name: "slot"
#             type {
#               type_kind: STRING
#             }
#           }
#           fields {
#             name: "criteriaParameters"
#             type {
#               type_kind: STRING
#             }
#           }
#           fields {
#             name: "gclId"
#             type {
#               type_kind: STRING
#             }
#           }
#           fields {
#             name: "customerId"
#             type {
#               type_kind: INT64
#             }
#           }
#           fields {
#             name: "adNetworkType"
#             type {
#               type_kind: STRING
#             }
#           }
#           fields {
#             name: "targetingCriteria"
#             type {
#               type_kind: STRUCT
#               struct_type {
#                 fields {
#                   name: "boomUserlistId"
#                   type {
#                     type_kind: INT64
#                   }
#                 }
#               }
#             }
#           }
#           fields {
#             name: "isVideoAd"
#             type {
#               type_kind: BOOL
#             }
#           }
#         }
#       }
#     }
#     fields {
#       name: "isTrueDirect"
#       type {
#         type_kind: BOOL
#       }
#     }
#     fields {
#       name: "campaignCode"
#       type {
#         type_kind: STRING
#       }
#     }
#   }
# }
#
# Schema Field of device column
#
# name: "device"
# type {
#   type_kind: STRUCT
#   struct_type {
#     fields {
#       name: "browser"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "browserVersion"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "browserSize"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "operatingSystem"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "operatingSystemVersion"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "isMobile"
#       type {
#         type_kind: BOOL
#       }
#     }
#     fields {
#       name: "mobileDeviceBranding"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "mobileDeviceModel"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "mobileInputSelector"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "mobileDeviceInfo"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "mobileDeviceMarketingName"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "flashVersion"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "javaEnabled"
#       type {
#         type_kind: BOOL
#       }
#     }
#     fields {
#       name: "language"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "screenColors"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "screenResolution"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "deviceCategory"
#       type {
#         type_kind: STRING
#       }
#     }
#   }
# }
#
# Schema Field of geoNetwork column
#
# name: "geoNetwork"
# type {
#   type_kind: STRUCT
#   struct_type {
#     fields {
#       name: "continent"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "subContinent"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "country"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "region"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "metro"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "city"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "cityId"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "networkDomain"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "latitude"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "longitude"
#       type {
#         type_kind: STRING
#       }
#     }
#     fields {
#       name: "networkLocation"
#       type {
#         type_kind: STRING
#       }
#     }
#   }
# }
#
# Schema Field of customDimensions column
#
# name: "customDimensions"
# type {
#   type_kind: ARRAY
#   array_element_type {
#     type_kind: STRUCT
#     struct_type {
#       fields {
#         name: "index"
#         type {
#           type_kind: INT64
#         }
#       }
#       fields {
#         name: "value"
#         type {
#           type_kind: STRING
#         }
#       }
#     }
#   }
# }
#
# Schema Field of hits column
#
# name: "hits"
# type {
#   type_kind: ARRAY
#   array_element_type {
#     type_kind: STRUCT
#     struct_type {
#       fields {
#         name: "hitNumber"
#         type {
#           type_kind: INT64
#         }
#       }
#       fields {
#         name: "time"
#         type {
#           type_kind: INT64
#         }
#       }
#       fields {
#         name: "hour"
#         type {
#           type_kind: INT64
#         }
#       }
#       fields {
#         name: "minute"
#         type {
#           type_kind: INT64
#         }
#       }
#       fields {
#         name: "isSecure"
#         type {
#           type_kind: BOOL
#         }
#       }
#       fields {
#         name: "isInteraction"
#         type {
#           type_kind: BOOL
#         }
#       }
#       fields {
#         name: "isEntrance"
#         type {
#           type_kind: BOOL
#         }
#       }
#       fields {
#         name: "isExit"
#         type {
#           type_kind: BOOL
#         }
#       }
#       fields {
#         name: "referer"
#         type {
#           type_kind: STRING
#         }
#       }
#       fields {
#         name: "page"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "pagePath"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "hostname"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "pageTitle"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "searchKeyword"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "searchCategory"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "pagePathLevel1"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "pagePathLevel2"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "pagePathLevel3"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "pagePathLevel4"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "transaction"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "transactionId"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "transactionRevenue"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "transactionTax"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "transactionShipping"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "affiliation"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "currencyCode"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "localTransactionRevenue"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "localTransactionTax"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "localTransactionShipping"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "transactionCoupon"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "item"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "transactionId"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "productName"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "productCategory"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "productSku"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "itemQuantity"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "itemRevenue"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "currencyCode"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "localItemRevenue"
#               type {
#                 type_kind: INT64
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "contentInfo"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "contentDescription"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "appInfo"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "name"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "version"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "id"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "installerId"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "appInstallerId"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "appName"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "appVersion"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "appId"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "screenName"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "landingScreenName"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "exitScreenName"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "screenDepth"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "exceptionInfo"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "description"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "isFatal"
#               type {
#                 type_kind: BOOL
#               }
#             }
#             fields {
#               name: "exceptions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "fatalExceptions"
#               type {
#                 type_kind: INT64
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "eventInfo"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "eventCategory"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "eventAction"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "eventLabel"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "eventValue"
#               type {
#                 type_kind: INT64
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "product"
#         type {
#           type_kind: ARRAY
#           array_element_type {
#             type_kind: STRUCT
#             struct_type {
#               fields {
#                 name: "productSKU"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "v2ProductName"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "v2ProductCategory"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "productVariant"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "productBrand"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "productRevenue"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "localProductRevenue"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "productPrice"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "localProductPrice"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "productQuantity"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "productRefundAmount"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "localProductRefundAmount"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "isImpression"
#                 type {
#                   type_kind: BOOL
#                 }
#               }
#               fields {
#                 name: "isClick"
#                 type {
#                   type_kind: BOOL
#                 }
#               }
#               fields {
#                 name: "customDimensions"
#                 type {
#                   type_kind: ARRAY
#                   array_element_type {
#                     type_kind: STRUCT
#                     struct_type {
#                       fields {
#                         name: "index"
#                         type {
#                           type_kind: INT64
#                         }
#                       }
#                       fields {
#                         name: "value"
#                         type {
#                           type_kind: STRING
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#               fields {
#                 name: "customMetrics"
#                 type {
#                   type_kind: ARRAY
#                   array_element_type {
#                     type_kind: STRUCT
#                     struct_type {
#                       fields {
#                         name: "index"
#                         type {
#                           type_kind: INT64
#                         }
#                       }
#                       fields {
#                         name: "value"
#                         type {
#                           type_kind: INT64
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#               fields {
#                 name: "productListName"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "productListPosition"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "productCouponCode"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "promotion"
#         type {
#           type_kind: ARRAY
#           array_element_type {
#             type_kind: STRUCT
#             struct_type {
#               fields {
#                 name: "promoId"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "promoName"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "promoCreative"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "promoPosition"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "promotionActionInfo"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "promoIsView"
#               type {
#                 type_kind: BOOL
#               }
#             }
#             fields {
#               name: "promoIsClick"
#               type {
#                 type_kind: BOOL
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "refund"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "refundAmount"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "localRefundAmount"
#               type {
#                 type_kind: INT64
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "eCommerceAction"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "action_type"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "step"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "option"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "experiment"
#         type {
#           type_kind: ARRAY
#           array_element_type {
#             type_kind: STRUCT
#             struct_type {
#               fields {
#                 name: "experimentId"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "experimentVariant"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "publisher"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "dfpClicks"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpMatchedQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpMeasurableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpRevenueCpm"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpRevenueCpc"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpViewableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpPagesViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpClicks"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpMatchedQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpMeasurableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpRevenueCpm"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpRevenueCpc"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpViewableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsenseBackfillDfpPagesViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpClicks"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpMatchedQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpMeasurableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpRevenueCpm"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpRevenueCpc"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpViewableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxBackfillDfpPagesViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxClicks"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxMatchedQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxMeasurableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxQueries"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxRevenue"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxViewableImpressions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adxPagesViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsUnitsViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsUnitsMatched"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "viewableAdsViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "measurableAdsViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsPagesViewed"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsClicked"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "adsRevenue"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "dfpAdGroup"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "dfpAdUnits"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "dfpNetworkId"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "customVariables"
#         type {
#           type_kind: ARRAY
#           array_element_type {
#             type_kind: STRUCT
#             struct_type {
#               fields {
#                 name: "index"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "customVarName"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "customVarValue"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "customDimensions"
#         type {
#           type_kind: ARRAY
#           array_element_type {
#             type_kind: STRUCT
#             struct_type {
#               fields {
#                 name: "index"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "value"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "customMetrics"
#         type {
#           type_kind: ARRAY
#           array_element_type {
#             type_kind: STRUCT
#             struct_type {
#               fields {
#                 name: "index"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "value"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "type"
#         type {
#           type_kind: STRING
#         }
#       }
#       fields {
#         name: "social"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "socialInteractionNetwork"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "socialInteractionAction"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "socialInteractions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "socialInteractionTarget"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "socialNetwork"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "uniqueSocialInteractions"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "hasSocialSourceReferral"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "socialInteractionNetworkAction"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "latencyTracking"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "pageLoadSample"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "pageLoadTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "pageDownloadTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "redirectionTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "speedMetricsSample"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "domainLookupTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "serverConnectionTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "serverResponseTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "domLatencyMetricsSample"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "domInteractiveTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "domContentLoadedTime"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "userTimingValue"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "userTimingSample"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "userTimingVariable"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "userTimingCategory"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "userTimingLabel"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "sourcePropertyInfo"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "sourcePropertyDisplayName"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "sourcePropertyTrackingId"
#               type {
#                 type_kind: STRING
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "contentGroup"
#         type {
#           type_kind: STRUCT
#           struct_type {
#             fields {
#               name: "contentGroup1"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "contentGroup2"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "contentGroup3"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "contentGroup4"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "contentGroup5"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "previousContentGroup1"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "previousContentGroup2"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "previousContentGroup3"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "previousContentGroup4"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "previousContentGroup5"
#               type {
#                 type_kind: STRING
#               }
#             }
#             fields {
#               name: "contentGroupUniqueViews1"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "contentGroupUniqueViews2"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "contentGroupUniqueViews3"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "contentGroupUniqueViews4"
#               type {
#                 type_kind: INT64
#               }
#             }
#             fields {
#               name: "contentGroupUniqueViews5"
#               type {
#                 type_kind: INT64
#               }
#             }
#           }
#         }
#       }
#       fields {
#         name: "dataSource"
#         type {
#           type_kind: STRING
#         }
#       }
#       fields {
#         name: "publisher_infos"
#         type {
#           type_kind: ARRAY
#           array_element_type {
#             type_kind: STRUCT
#             struct_type {
#               fields {
#                 name: "dfpClicks"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpMatchedQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpMeasurableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpRevenueCpm"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpRevenueCpc"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpViewableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpPagesViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpClicks"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpMatchedQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpMeasurableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpRevenueCpm"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpRevenueCpc"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpViewableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsenseBackfillDfpPagesViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpClicks"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpMatchedQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpMeasurableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpRevenueCpm"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpRevenueCpc"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpViewableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxBackfillDfpPagesViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxClicks"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxMatchedQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxMeasurableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxQueries"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxRevenue"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxViewableImpressions"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adxPagesViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsUnitsViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsUnitsMatched"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "viewableAdsViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "measurableAdsViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsPagesViewed"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsClicked"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "adsRevenue"
#                 type {
#                   type_kind: INT64
#                 }
#               }
#               fields {
#                 name: "dfpAdGroup"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "dfpAdUnits"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#               fields {
#                 name: "dfpNetworkId"
#                 type {
#                   type_kind: STRING
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# # Step 2: Explore, Visualize and Interpret Results
#
# In this analysis, I focused on addressing below questions:
# * How much traffic did the website get over time?
# * Which channel drove the most traffic to the website in 2017?
# * Which channel generated the most transactions and revenue in 2017?
# * What were the most popular pages in 2017?
# * How did the checkout process of Apparel product category perform in 2017?

# %% [markdown]
# #### How much traffic did the website get over time?
# #### Which channel drove the most traffic to the website in 2016?

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

# How much traffic did the website get over time?
query1 = """
        SELECT date
        , SUM(totals.pageviews) AS pageviews
        FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
        WHERE _TABLE_SUFFIX BETWEEN '20160801' AND '20161230'
        GROUP BY 1
        ORDER BY 1
        """

result1 = client.query(query1).result().to_dataframe()
result1['date'] = pd.to_datetime(result1['date'])
result1.plot(y='pageviews', x='date', kind='line', color='royalblue', title='Pageviews Over Time', ax=axes[0])

# Which channel drove the most traffic to the website?
query2 = """
        SELECT channelgrouping AS channel
        , SUM(totals.pageviews) AS pageviews
        FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
        WHERE _TABLE_SUFFIX BETWEEN '20160101' AND '20161230'
        GROUP BY 1
        ORDER BY 2 DESC
        """
result2 = client.query(query2).result().to_dataframe()
result2.plot(y='pageviews', x='channel', kind='bar', color='royalblue', legend=False, title='Pageviews Breakdown By Channel - 2016', ax=axes[1])
# Out:
# <Axes: title={'center': 'Pageviews Breakdown By Channel - 2016'}, xlabel='channel'>

# %% [markdown]
# **From the line chart, we can see that the traffic decreased to the lowest percentage by the end of Aug 2016. The majority of traffic came from organic search, referral, and direct channels.**

# %% [markdown]
# #### Which channel generated the most transactions and revenue in 2016?

# %%
# Which channel generated the most transactions and revenue?
query = """
        SELECT channelgrouping AS channel
        , COUNT(DISTINCT hits.transaction.transactionid) AS transactions
        , SUM(hits.transaction.transactionrevenue)/1000000 AS revenue
        , COUNT(DISTINCT hits.transaction.transactionid)/SUM(totals.visits) AS conversion_rate
        FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
        , UNNEST(hits) AS hits
        WHERE _TABLE_SUFFIX BETWEEN '20160801' AND '20161230'
        GROUP BY 1
        ORDER BY 2 DESC
        """
result = client.query(query).result().to_dataframe()
fig, ax = plt.subplots(figsize=(10,7))
result.plot(y=['transactions', 'revenue'], x='channel', kind='bar', secondary_y='revenue', ax=ax)
ax.set_xticklabels(labels=result['channel'], rotation=45)
# Out:
# [Text(0, 0, 'Referral'),
#  Text(1, 0, 'Organic Search'),
#  Text(2, 0, 'Direct'),
#  Text(3, 0, 'Paid Search'),
#  Text(4, 0, 'Display'),
#  Text(5, 0, 'Social'),
#  Text(6, 0, 'Affiliates'),
#  Text(7, 0, '(Other)')]

# %% [markdown]
# Referral channel generated the most transactions and revenue, although the amount of traffic driven by this channel was less than half of that driven by organic search channel. Direct channel came at third place in the number of transactions, after organic search channel, yet it generated more revenue. Similarly, display also appeared as a promising channel.
#
# Following this insight, we can:
# * Look further into the product category distribution of each channel to evaluate which channel would be more effective to promote which product category
# * Increase budget for display channel

# %% [markdown]
# #### What were the most popular pages in 2016?

# %%
# What were the most popular pages, excluding pages in the checkout process?
query = """
        SELECT hits.page.pagepath AS page
        , SUM(totals.pageviews) AS pageviews
        , ROUND(AVG(totals.timeonsite), 1) AS avg_time_on_page
        , COUNT(DISTINCT fullvisitorid) AS users
        , ROUND(100*SUM(totals.bounces)/SUM(totals.visits),2) AS bounce_rate
        FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
        , UNNEST(hits) AS hits
        WHERE _TABLE_SUFFIX BETWEEN '20160101' AND '20171230'
        AND hits.page.pagepath NOT LIKE '%html'
        GROUP BY 1
        ORDER BY pageviews DESC
        """
result = client.query(query).result().to_dataframe()
result.head(20)
# Out:
#                                                  page  pageviews  \
# 0                                               /home    6915538
# 1     /google+redesign/apparel/men++s/men++s+t+shirts    1909502
# 2                             /google+redesign/office    1756629
# 3                               /google+redesign/bags    1648114
# 4                        /google+redesign/electronics    1640051
# 5                          /google+redesign/drinkware    1556022
# 6              /google+redesign/shop+by+brand/youtube    1453032
# 7                            /google+redesign/apparel    1241606
# 8    /google+redesign/apparel/men++s/men++s+outerwear    1119797
# 9                    /google+redesign/accessories/fun    1113178
# 10   /google+redesign/bags/water+bottles+and+tumblers    1020838
# 11        /google+redesign/office/notebooks++journals     858728
# 12  /google+redesign/apparel/women+s/women+s+t+shirts     816709
# 13        /google+redesign/office/writing+instruments     790032
# 14                  /google+redesign/apparel/headgear     787747
# 15              /google+redesign/shop+by+brand/google     780693
# 16                       /google+redesign/accessories     748775
# 17                         /google+redesign/lifestyle     745263
# 18           /google+redesign/drinkware/mugs+and+cups     703560
# 19               /google+redesign/bags/backpacks/home     692275
#
#     avg_time_on_page   users  bounce_rate
# 0              342.0  544331        29.45
# 1              686.5   44760         9.11
# 2              871.2   31898         1.88
# 3              739.1   36450         4.74
# 4              739.7   40526         3.42
# 5              783.1   35832         6.33
# 6              378.2  104525        25.35
# 7              683.0   36677         4.21
# 8              642.6   25872         4.72
# 9              827.4   24763         0.91
# 10             895.2   17085         1.60
# 11             869.1   15661         2.59
# 12             867.0   13577         3.87
# 13            1048.0   11850         0.94
# 14             773.4   18997         5.53
# 15             559.6   32542         2.52
# 16             778.9   21710         2.45
# 17             884.7   10967         0.79
# 18             750.4   20666         1.49
# 19             625.3   17984         1.54

# %% [markdown]
# **From the individual page performance table, we can idenfity pages with good user engagement (high time on page and low bounce rate) but low traffic. With this information, we can implement appropriate SEO strategies to further enhance their performance.**

# %% [markdown]
# #### How did the checkout process of Apparel product category perform?

# %%
# How did the checkout process of Apparel product category perform?
query = """
        WITH checkout_process AS (
        SELECT CASE WHEN hits.page.pagepath = '/yourinfo.html' THEN '1. Add billing and shipping information'
                    WHEN hits.page.pagepath = '/payment.html' THEN '2. Add payment method'
                    WHEN hits.page.pagepath = '/revieworder.html' THEN '3. Review order'                 
                    WHEN hits.page.pagepath = '/ordercompleted.html' THEN '4. Order completed'
                END AS action
        , fullvisitorid AS user_id
        FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
        , UNNEST(hits) AS hits
        , UNNEST(hits.product) AS product
        WHERE _TABLE_SUFFIX BETWEEN '20160101' AND '20161230'
        AND hits.ecommerceaction.action_type IN ('5','6')
        AND product.v2ProductCategory IN ('Apparel')
        )
        
        SELECT action
        , COUNT(DISTINCT user_id) AS users
        FROM checkout_process
        GROUP BY 1
        ORDER BY 1
        """
result = client.query(query).result().to_dataframe()

fig = go.Figure(go.Funnel(y = result['action'], x = result['users'], textposition = 'inside', textinfo = 'value+percent initial'))
fig.update_layout(title_text = 'Apparel Checkout Funnel')
fig.show()
# Out:
# <div>                            <div id="7ac74dfa-5805-491d-8db3-5385d4f73ae8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ac74dfa-5805-491d-8db3-5385d4f73ae8")) {                    Plotly.newPlot(                        "7ac74dfa-5805-491d-8db3-5385d4f73ae8",                        [{"textinfo":"value+percent initial","textposition":"inside","x":[2501,2187,1614,1731],"y":["1. Add billing and shipping information","2. Add payment method","3. Review order","4. Order completed"],"type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"hi ...
#
# var gd = document.getElementById('7ac74dfa-5805-491d-8db3-5385d4f73ae8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display =

# %% [markdown]
# #### One noticable insight about the checkout process is that the number of customers who completed order is larger than those who reviewed order, which could indicate a tracking issue from step 3 to step 4. Therefore, we could examine it further.
